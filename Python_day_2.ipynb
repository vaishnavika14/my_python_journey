# %% [markdown]
# # Python day 2
#
# #### Topic covered:
# <h4><pre>
# - if
# - elif
# - else
# - Comparison operators
# - and/or
# -Data types in conditions
# </pre></h2=4>

# %% [markdown]
# ### "if"  statement

# %% [markdown]
# if the temperature is more than 30 then then "it's hot " should be print

# %%
temperature = 35

if temperature > 30:
    print("It's hot")
# Out:
# It's hot

# %% [markdown]
# <b> Note: indentation is very important

# %% [markdown]
# age = 31
#
# if age >= 18
#     print("You are an adult")
#
# Got the error
#
# <pre>
#      Cell In[154], line 3
#     if age >= 18
#                 ^
# SyntaxError: expected ':'
#
#
# <b> ":" at the end of the condition is required </b>
#
# </pre>

# %%
age = 31

if age >= 18:
    print("You are an adult")
# Out:
# You are an adult

# %% [markdown]
# ### "if else"  statement  for 2 possiblities

# %%
age = 15

if age >= 18:
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# You are a minor

# %%
age = 27

if age >= 18:
    print("You are an adult")
else:
    print("You are a minor")
# Out:
# You are an adult

# %% [markdown]
# ### elif — multiple possibilities

# %% [markdown]
# marks = 75
#
# if marks >= 90:
#     print("A")
# elif marks >= 75:
#     print("B")
# elif marks >= 50:
#     print("C")
# else:
#     print("Fail")

# %%
marks = 90

if marks >= 90:
    print("A")
elif marks >= 75:
    print("B")
elif marks >= 50:
    print("C")
else:
    print("Fail")
# Out:
# A

# %%
marks = 35

if marks >= 90:
    print("A")
elif marks >= 75:
    print("B")
elif marks >= 50:
    print("C")
else:
    print("Fail")
# Out:
# Fail

# %% [markdown]
# ### Comparison operators <br/>
#
#  <br/> a == b     # equal
#  <br/> a != b     # not equal
#  <br/> a > b      # greater than
#  <br/> a < b      # less than
#  <br/> a >= b     # greater than or equal
#  <br/> a <= b     # less than or equal
#
# = → put something into a box
#
# == → ask whether two things are equal

# %% [markdown]
# ### Combinning conditions
#
# we combine condition using
# and -> both condition should be true
# or -> any one conditionals should be true
# not -> not true
#
# lets look at some examples

# %%
age = 31
experience = 3

if age >= 18 and experience >= 2:
    print("Eligible")
# Out:
# Eligible

# %%
skill = "Python"

if skill == "Python" or skill == "Java":
    print("Programming skill")
# Out:
# Programming skill

# %% [markdown]
# ###  Exercise 1
#
# Write code that prints:
# If the confidence level is greather than equal to 0.80 then only accept the prediction else print the message that "sent for human review"
# <pre>
# Model
#   ↓
# Prediction
#   ↓
# Confidence score
#   ↓
# if confidence is high → use prediction
# else → human review
# </pre>

# %%
confidence = 0.92

if confidence >= 0.80:
    print("Accept prediction")
else:
    print("Send for human review")
# Out:
# Accept prediction

# %% [markdown]
# ### Exercise 2
# Write code that prints:
# "Hot" if temperature > 30
# "Warm" if temperature is between 20 and 30
# "Cold" otherwise
# </br>
# Given temperature=35

# %%
temp = float(input("Enter the today temperature:"))

if temp>30:
    print("It's hot today!!")
elif temp>20 and temp<30:
    print("It's warm today!!")
else:
    print("It's cold  today!!")
# Out:
# Enter the today temperature: 35
# It's hot today!!

# %%
temp = float(input("Enter the today temperature:"))

if temp>30:
    print("It's hot today!!")
elif temp>20 and temp<30:
    print("It's warm today!!")
else:
    print("It's cold  today!!")
# Out:
# Enter the today temperature: 25
# It's warm today!!

# %%
temp = float(input("Enter the today temperature:"))

if temp>30:
    print("It's hot today!!")
elif temp>20 and temp<30:
    print("It's warm today!!")
else:
    print("It's cold  today!!")
# Out:
# Enter the today temperature: 15
# It's cold  today!!

# %% [markdown]
# ### Exercise 3
# Write code
# Ask the user for their marks.
# <pre>90–100 → A
# 75–89  → B
# 50–74  → C
# Below 50 → Fail</pre>

# %%
marks = float(input("Enter your marks?"))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 75 and marks <= 89:
    print("Grade: B")
elif marks >= 50 and marks <= 74:
    print("Grade: C")
elif marks > 50:
    print("FAIL")
else:
    print("Invalid !!")
# Out:
# Enter your marks? 95
# Grade: A

# %%
marks = float(input("Enter your marks?"))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 75 and marks <= 89:
    print("Grade: B")
elif marks >= 50 and marks <= 74:
    print("Grade: C")
elif marks > 50:
    print("FAIL")
else:
    print("Invalid !!")
# Out:
# Enter your marks? 101
# FAIL

# %% [markdown]
# Invalid doesnt work hence updating my code

# %%
marks = float(input("Enter your marks?"))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 75 and marks <= 89:
    print("Grade: B")
elif marks >= 50 and marks <= 74:
    print("Grade: C")
elif marks > 50:
    if marks >= 0 and marks < 50:
        print("FAIL")
    elif marks > 0 or marks < 100:
        print("Invalid !!")
# Out:
# Enter your marks? 101
# Invalid !!

# %%
marks = float(input("Enter your marks?"))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 75 and marks <= 89:
    print("Grade: B")
elif marks >= 50 and marks <= 74:
    print("Grade: C")
elif marks > 50:
    if marks >= 0 and marks < 50:
        print("FAIL")
    elif marks > 0 or marks < 100:
        print("Invalid !!")
# Out:
# Enter your marks? 95
# Grade: A

# %%
marks = float(input("Enter your marks?"))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 75 and marks <= 89:
    print("Grade: B")
elif marks >= 50 and marks <= 74:
    print("Grade: C")
elif marks > 50:
    if marks >= 0 and marks < 50:
        print("FAIL")
    elif marks > 0 or marks < 100:
        print("Invalid !!")
# Out:
# Enter your marks? 56
# Grade: C

# %%
marks = float(input("Enter your marks?"))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 75 and marks <= 89:
    print("Grade: B")
elif marks >= 50 and marks <= 74:
    print("Grade: C")
elif marks > 50:
    if marks >= 0 and marks < 50:
        print("FAIL")
    elif marks > 0 or marks < 100:
        print("Invalid !!")
# Out:
# Enter your marks? 85
# Grade: B

# %%
marks = float(input("Enter your marks?"))

if marks >= 90 and marks <= 100:
    print("Grade: A")
elif marks >= 75 and marks <= 89:
    print("Grade: B")
elif marks >= 50 and marks <= 74:
    print("Grade: C")
elif marks > 50:
    if marks >= 0 and marks < 50:
        print("FAIL")
    elif marks > 0 or marks < 100:
        print("Invalid !!")
# Out:
# Enter your marks? 35

# %% [markdown]
# ### Exercise 4
# <pre>
# Create a login check:
# correct_username = "admin"
# correct_password = "1234"
#
# Ask the user for username and password.
#
# If both are correct:
#
# Login successful
#
#
# Otherwise:
#
# Invalid username or password
# </pre>

# %%
correct_username = "admin"
correct_password = "1234"

username = input("Enter the username:")
password = int(input("Enter the password:"))

if username==correct_username and password==correct_password:
    print("Login Sucessful!")
else:
    print("Invalid username or password !!")
# Out:
# Enter the username: admin
# Enter the password: 1234
# Invalid username or password !!

# %% [markdown]
# The reason why this didnt work for me though the logic is correct because password data type is int and correct_password is a string datatype hence comparing comparing:<pre>
# 1234        → int
# "1234"      → string
# They are different data types.
# so when password == correct_password evaluates like this 1234 == "1234" and returns false
#    </p
# )re>>

# %%
print(type(password))
print(type(correct_password))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# #### Corrected code

# %%
correct_username = "admin"
correct_password = "1234"

username = input("Enter the username:")
password = input("Enter the password:")

if username==correct_username and password==correct_password:
    print("Login Sucessful!")
else:
    print("Invalid username or password !!")
# Out:
# Enter the username: admin
# Enter the password: 1234
# Login Sucessful!

# %%
correct_username = "admin"
correct_password = "1234"

username = input("Enter the username:")
password = input("Enter the password:")

if username==correct_username and password==correct_password:
    print("Login Sucessful!")
else:
    print("Invalid username or password !!")
# Out:
# Enter the username: asim
# Enter the password: 1234
# Invalid username or password !!

# %%
correct_username = "admin"
correct_password = "1234"

username = input("Enter the username:")
password = input("Enter the password:")

if username==correct_username and password==correct_password:
    print("Login Sucessful!")
else:
    print("Invalid username or password !!")
# Out:
# Enter the username: admin
# Enter the password: 1256
# Invalid username or password !!

# %% [markdown]
# ### Exercise 5
#
# <pre> Create an AI-style prediction decision:
#
# confidence = 0.73
#
# If confidence is:
#
# >=0.80 → "High confidence"
# 0.50–0.79 → "Medium confidence"
# < 0.50 → "Low confidence"
# </pre>

# %%
conf = float(input("enter the confidence rate:"))

if conf>=0.80 and conf<=1.0:
    print("High confidence")
elif conf>=0.50 and conf<=0.79:
    print("Medium confidence")
elif conf>=0 and conf<=0.5:
    print("low confidence")
else:
    print("Invalid range")
# Out:
# enter the confidence rate: 0.73
# Medium confidence

# %%
conf = float(input("enter the confidence rate:"))

if conf>=0.80 and conf<=1.0:
    print("High confidence")
elif conf>=0.50 and conf<=0.79:
    print("Medium confidence")
elif conf>=0 and conf<=0.5:
    print("low confidence")
else:
    print("Invalid range")
# Out:
# enter the confidence rate: 0.89
# High confidence

# %%
conf = float(input("enter the confidence rate:"))

if conf>=0.80 and conf<=1.0:
    print("High confidence")
elif conf>=0.50 and conf<=0.79:
    print("Medium confidence")
elif conf>=0 and conf<=0.5:
    print("low confidence")
else:
    print("Invalid range")
# Out:
# enter the confidence rate: 0.14
# low confidence

# %%
conf = float(input("enter the confidence rate:"))

if conf>=0.80 and conf<=1.0:
    print("High confidence")
elif conf>=0.50 and conf<=0.79:
    print("Medium confidence")
elif conf>=0 and conf<=0.5:
    print("Medium confidence")
else:
    print("Invalid range")
# Out:
# enter the confidence rate: 1.2
# Invalid range

# %% [markdown]
# # See you at day 3 !! keep going!! keep coding !!
