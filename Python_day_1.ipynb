# %% [markdown]
#  #                                                  Python learning from scratch
# #  Day 1

# %% [markdown]
# ### The most common function of Python
# ### print() tells Python:Display this on the screen.

# %%
print("Hello, iris!")
# Out:
# Hello, iris!

# %%
print(Hello, iris!)
# Out:
#   Cell In[5], line 1
#     print(Hello, iris!)
#                      ^
# SyntaxError: invalid syntax

# %%
print('Hello, iris!')
# Out:
# Hello, iris!

# %% [markdown]
# <b> The text that needs to be printed should given between "" or ''

# %%
print("hi, iris \nyou can print anything you want ")
# Out:
# hi, iris
# you can print anything you want

# %% [markdown]
# <b> For next line \n

# %% [markdown]
# ### For storing information used Variables
# In simple term variables are labeled containers which allows us store the data

# %%
name = "iris"
age = 31
weight = 91 

print("your name :",name)
print("your age :",age)
print("your weight : ",weight)
# Out:
# your name : iris
# your age : 31
# your weight :  91

# %%
print(name)
# Out:
# iris

# %%
print(age)
# Out:
# 31

# %%
print(weight)
# Out:
# 91

# %% [markdown]
# ### To the data types of python use <b>""type()" </b>
#
# Data types of python:  int, float, str, list, dict, tuple, set, bool

# %%
name = "iris"
age = 31
height = 170
learning_python = True

print(type(name))
print(type(age))
print(type(height))
print(type(learning_python))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# #### Operators
# The operators we discuss here are:
# Addition
# Subtraction
# Multiplicion
# Division
# Floor division (rounds up to the nearest whole number after division)
# Remainder
# Power

# %%
a = 10
b = 5
c = 3

print("the values are a=",a,", b=",b,", c=",c)

print("Addition :", a + b)
print("Subtraction :", a - b)
print("multiplication :", a * b)
print("Division :", a / b)

print("floor division :", a // c)
print("Remainder :", a % c)
print("power :", a ** c)
# Out:
# the values are a= 10 , b= 5 , c= 3
# Addition : 15
# Subtraction : 5
# multiplication : 50
# Division : 2.0
# floor division : 3
# Remainder : 1
# power : 1000

# %% [markdown]
# #### Strings

# %%
name_1 = "Iris"
name_2 = "isis"

print("the names are ", name_1,"and", name_2)
# Out:
# the names are  Iris and isis

# %% [markdown]
# #### Combining strings

# %%
game_name=name_1 + " " + name_2

print(" The game name is", game_name)
# Out:
#  The game name is Iris isis

# %% [markdown]
# #### Combining strings using fstring

# %%
print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is iris and I am 31 years old.

# %% [markdown]
# #### Getting input from a user

# %%
colour = input("what your favourite colour?")
# Out:
# what your favourite colour? pink

# %%
print(f"Your favourite color is {colour}.")
# Out:
# Your favourite color is pink .

# %%
num1 = input("select a number from 1 to 9 ")
# Out:
# select a number from 1 to 9  55

# %%
print(type(num1))
# Out:
# <class 'str'>

# %%
num2 = int(input("select a number from 1 to 9 "))
# Out:
# select a number from 1 to 9  5

# %%
print(type(num2))
# Out:
# <class 'int'>

# %% [markdown]
# ### Exercise 1
#
# Get the name and age of the person and display the age of the person next year

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"Hello {name}!")
print(f"You are {age} years old.")
print(f"Next year you will be {age + 1}.")
# Out:
# Enter your name:  isis
# Enter your age:  5
# Hello isis!
# You are 5 years old.
# Next year you will be 6.

# %% [markdown]
# ### Exercise 2
#
# The height and weight of the person is weight = 91kg
# height = 1.69 feet calculate the BMI

# %%
weight = 91
height = 1.69

bmi = weight / (height ** 2)

print(bmi)
# Out:
# 31.861629494765594

# %% [markdown]
# <b> or

# %%
wei = int(input("enter the weight :"))
Hei = int(input("enter the height :"))

bmi1 = weight / (height ** 2)

print("the BMI is : ", bmi)
# Out:
# enter the weight : 91
# enter the height : 1.69
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 2
#       1 wei = int(input("enter the weight :"))
# ----> 2 Hei = int(input("enter the height :"))
#       4 bmi1 = weight / (height ** 2)
#       6 print("the BMI is : ", bmi)
#
# ValueError: invalid literal for int() with base 10: '1.69'

# %% [markdown]
# #### What i learned
#
# <i> 1.69 is a float data type because it contains a decimal value.
#
# An int (integer) represents a whole number, such as 1, 10, or 100.
#
# So, when I tried to use 1.69 where Python expected an int, I got an error.
#
# Key takeaway:
# int → whole numbers → 10, 25, 100
# float → decimal numbers → 1.69, 10.5, 25.75

# %%
wei = int(input("enter the weight :"))
Hei = float(input("enter the height :"))

bmi1 = weight / (height ** 2)

print("the BMI is : ", bmi)
# Out:
# enter the weight : 91
# enter the height : 1.69
# the BMI is :  31.861629494765594

# %% [markdown]
# ### Exercise 3
#
# Connect these string using fstring function :  name = "isis",
# age = 31 ,
# city = "goa"

# %%
name = "isis"
age = 31
city = "goa"

print(f"my name is {name} , my age is {age} and I live in {city}")
# Out:
# my name is isis , my age is 31 and I live in goa

# %% [markdown]
# ### Exercise 4
#
# Calculate the are of the reactangle if length = 10 , width = 5

# %%
#length = 10
#width = 5

print("To calculate the area of rectangle enter the lenght and width")
length = int(input("enter the length"))
width = int(input("enter the width"))

area = length * width 

print(f"the area of the rectangle is {area}.")
# Out:
# To calculate the area of rectangle enter the lenght and width
# enter the length 10
# enter the width 5
# the area of the rectangle is 50.

# %% [markdown]
# ## 🌟 End of Day 1
#
# That's the end o****Day 1** of my Python journey! 🐍
#
# I learned, practiced, made mistakes, and learned from them.
#
# **One day at a time. One concept at a time.**
#
# See you on **Day 2! 🚀**
